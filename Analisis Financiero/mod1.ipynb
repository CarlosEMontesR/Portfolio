# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels

# %%
fbcsv = pd.read_csv("META.csv")

# %%
fbcsv.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2015-01-02  78.580002  78.930000  77.699997  78.449997  78.289124  18177500
# 1  2015-01-05  77.980003  79.250000  76.860001  77.190002  77.031708  26452200
# 2  2015-01-06  77.230003  77.589996  75.360001  76.150002  75.993835  27399300
# 3  2015-01-07  76.760002  77.360001  75.820000  76.150002  75.993835  22045300
# 4  2015-01-08  76.739998  78.230003  76.080002  78.180000  78.019676  23961000

# %%
df = pd.DataFrame(fbcsv)

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2015-01-02   78.580002   78.930000   77.699997   78.449997   78.289124
# 1     2015-01-05   77.980003   79.250000   76.860001   77.190002   77.031708
# 2     2015-01-06   77.230003   77.589996   75.360001   76.150002   75.993835
# 3     2015-01-07   76.760002   77.360001   75.820000   76.150002   75.993835
# 4     2015-01-08   76.739998   78.230003   76.080002   78.180000   78.019676
# ...          ...         ...         ...         ...         ...         ...
# 1505  2020-12-23  266.890015  272.170013  266.230011  268.109985  267.560150
# 1506  2020-12-24  268.880005  270.399994  266.200012  267.399994  266.851624
# 1507  2020-12-28  268.739990  277.299988  265.660004  277.000000  276.431976
# 1508  2020-12-29  276.950012  280.510010  276.279999  276.779999  276.212402
# 1509  2020-12-30  277.950012  278.079987  271.709991  271.869995  271.312469
#
#         Volume
# 0     18177500
# ...

# %%
fb = pd.DataFrame(fbcsv)

# %%
fb.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2015-01-02  78.580002  78.930000  77.699997  78.449997  78.289124  18177500
# 1  2015-01-05  77.980003  79.250000  76.860001  77.190002  77.031708  26452200
# 2  2015-01-06  77.230003  77.589996  75.360001  76.150002  75.993835  27399300
# 3  2015-01-07  76.760002  77.360001  75.820000  76.150002  75.993835  22045300
# 4  2015-01-08  76.739998  78.230003  76.080002  78.180000  78.019676  23961000

# %%
fb.index
# Out:
# RangeIndex(start=0, stop=1510, step=1)

# %%
fb.index[0]
# Out:
# 0

# %%
fb.index[-1]
# Out:
# 1509

# %%
fb.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
fb.shape
# Out:
# (1510, 7)

# %%
fb.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1510.000000  1510.000000  1510.000000  1510.000000  1510.000000
# mean    158.250815   160.028159   156.419338   158.314258   157.989600
# std      51.122032    51.880700    50.369325    51.147696    51.042807
# min      74.040001    74.830002    72.000000    74.050003    73.898148
# 25%     117.744999   118.672499   116.757501   117.714998   117.473599
# 50%     161.529999   163.860001   159.504998   162.139999   161.807496
# 75%     186.779999   188.535000   184.550003   186.897495   186.514225
# max     300.160004   304.670013   293.049988   303.910004   303.286774
#
#              Volume
# count  1.510000e+03
# mean   2.259598e+07
# std    1.346760e+07
# min    5.913100e+06
# 25%    1.457165e+07
# 50%    1.914995e+07
# 75%    2.566285e+07
# max    1.698037e+08

# %%
fb2020 = fb.loc['2020-01-01':'2020-12-31']

# %%
plt.figure(figsize=(10,8))
fb['Close'].plot()
plt.show()

# %%
fb[['Open', 'Close']]
# Out:
#             Open       Close
# 0      78.580002   78.449997
# 1      77.980003   77.190002
# 2      77.230003   76.150002
# 3      76.760002   76.150002
# 4      76.739998   78.180000
# ...          ...         ...
# 1505  266.890015  268.109985
# 1506  268.880005  267.399994
# 1507  268.739990  277.000000
# 1508  276.950012  276.779999
# 1509  277.950012  271.869995
#
# [1510 rows x 2 columns]

# %%
fb['Price1'] = fb['Close'].shift(-1) #Precio de cierre anterior

# %%
fb.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2015-01-02  78.580002  78.930000  77.699997  78.449997  78.289124
# 1  2015-01-05  77.980003  79.250000  76.860001  77.190002  77.031708
# 2  2015-01-06  77.230003  77.589996  75.360001  76.150002  75.993835
# 3  2015-01-07  76.760002  77.360001  75.820000  76.150002  75.993835
# 4  2015-01-08  76.739998  78.230003  76.080002  78.180000  78.019676
#
#      Volume     Price1
# 0  18177500  77.190002
# 1  26452200  76.150002
# 2  27399300  76.150002
# 3  22045300  78.180000
# 4  23961000  77.739998

# %%
fb['PriceDiff'] = fb['Price1'] - fb['Close']

# %%
fb.head(10)
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2015-01-02  78.580002  78.930000  77.699997  78.449997  78.289124
# 1  2015-01-05  77.980003  79.250000  76.860001  77.190002  77.031708
# 2  2015-01-06  77.230003  77.589996  75.360001  76.150002  75.993835
# 3  2015-01-07  76.760002  77.360001  75.820000  76.150002  75.993835
# 4  2015-01-08  76.739998  78.230003  76.080002  78.180000  78.019676
# 5  2015-01-09  78.199997  78.620003  77.199997  77.739998  77.580574
# 6  2015-01-12  77.839996  78.000000  76.209999  76.720001  76.562668
# 7  2015-01-13  77.230003  78.080002  75.849998  76.449997  76.293213
# 8  2015-01-14  76.419998  77.199997  76.029999  76.279999  76.123573
# 9  2015-01-15  76.400002  76.570000  73.540001  74.050003  73.898148
#
#      Volume     Price1  PriceDiff
# 0  18177500  77.190002  -1.259995
# 1  26452200  76.150002  -1.040000
# 2  27399300  76.150002   0.000000
# 3  22045300  78.180000   2.029998
# ...

# %%
fb['Return'] = fb['PriceDiff']/fb['Close']

# %%
fb.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2015-01-02  78.580002  78.930000  77.699997  78.449997  78.289124
# 1  2015-01-05  77.980003  79.250000  76.860001  77.190002  77.031708
# 2  2015-01-06  77.230003  77.589996  75.360001  76.150002  75.993835
# 3  2015-01-07  76.760002  77.360001  75.820000  76.150002  75.993835
# 4  2015-01-08  76.739998  78.230003  76.080002  78.180000  78.019676
#
#      Volume     Price1  PriceDiff    Return
# 0  18177500  77.190002  -1.259995 -0.016061
# 1  26452200  76.150002  -1.040000 -0.013473
# 2  27399300  76.150002   0.000000  0.000000
# 3  22045300  78.180000   2.029998  0.026658
# 4  23961000  77.739998  -0.440002 -0.005628

# %%
fb['Direction'] = [1 if fb.loc[ei, 'PriceDiff'] > 0 else -1 for ei in fb.index]

# %%
fb.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2015-01-02  78.580002  78.930000  77.699997  78.449997  78.289124
# 1  2015-01-05  77.980003  79.250000  76.860001  77.190002  77.031708
# 2  2015-01-06  77.230003  77.589996  75.360001  76.150002  75.993835
# 3  2015-01-07  76.760002  77.360001  75.820000  76.150002  75.993835
# 4  2015-01-08  76.739998  78.230003  76.080002  78.180000  78.019676
#
#      Volume     Price1  PriceDiff    Return  Direction
# 0  18177500  77.190002  -1.259995 -0.016061         -1
# 1  26452200  76.150002  -1.040000 -0.013473         -1
# 2  27399300  76.150002   0.000000  0.000000         -1
# 3  22045300  78.180000   2.029998  0.026658          1
# 4  23961000  77.739998  -0.440002 -0.005628         -1

# %%
#Media Movil
fb['Average3'] = (fb['Close'] + fb['Close'].shift(1) + fb['Close'].shift(2))/3

# %%
fb.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2015-01-02  78.580002  78.930000  77.699997  78.449997  78.289124
# 1  2015-01-05  77.980003  79.250000  76.860001  77.190002  77.031708
# 2  2015-01-06  77.230003  77.589996  75.360001  76.150002  75.993835
# 3  2015-01-07  76.760002  77.360001  75.820000  76.150002  75.993835
# 4  2015-01-08  76.739998  78.230003  76.080002  78.180000  78.019676
#
#      Volume     Price1  PriceDiff    Return  Direction   Average3
# 0  18177500  77.190002  -1.259995 -0.016061         -1        NaN
# 1  26452200  76.150002  -1.040000 -0.013473         -1        NaN
# 2  27399300  76.150002   0.000000  0.000000         -1  77.263334
# 3  22045300  78.180000   2.029998  0.026658          1  76.496669
# 4  23961000  77.739998  -0.440002 -0.005628         -1  76.826668

# %%
#Media movil sobre cualquier numero de dias
fb['MA40'] = fb['Close'].rolling(40).mean() #40 Días
fb['MA200'] = fb['Close'].rolling(200).mean() #200 Días

# %%
fb['Close'].plot()
fb['MA40'].plot()
fb['MA200'].plot()
# Out:
# <Axes: >

# %%
ms = pd.DataFrame(pd.read_csv('MSFT.csv'))

# %%
ms.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2015-01-02  46.660000  47.419998  46.540001  46.759998  40.305370  27913900
# 1  2015-01-05  46.369999  46.730000  46.250000  46.330002  39.934723  39673900
# 2  2015-01-06  46.380001  46.750000  45.540001  45.650002  39.348598  36447900
# 3  2015-01-07  45.980000  46.459999  45.490002  46.230000  39.848541  29114100
# 4  2015-01-08  46.750000  47.750000  46.720001  47.590000  41.020802  29645200

# %%
ms['MA10'] = ms['Close'].rolling(10).mean() #Señal rápida
ms['MA50'] = ms['Close'].rolling(50).mean() #Señal lenta

# %%
ms['Close'].plot(legend=True)
ms['MA10'].plot(legend=True)
ms['MA50'].plot(legend=True)
# Out:
# <Axes: >

# %%
ms['Shares'] = [1 if ms.loc[ei, 'MA10']>ms.loc[ei, 'MA50'] else 0 for ei in ms.index]

# %%
ms
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2015-01-02   46.660000   47.419998   46.540001   46.759998   40.305370
# 1     2015-01-05   46.369999   46.730000   46.250000   46.330002   39.934723
# 2     2015-01-06   46.380001   46.750000   45.540001   45.650002   39.348598
# 3     2015-01-07   45.980000   46.459999   45.490002   46.230000   39.848541
# 4     2015-01-08   46.750000   47.750000   46.720001   47.590000   41.020802
# ...          ...         ...         ...         ...         ...         ...
# 1505  2020-12-23  223.110001  223.559998  220.800003  221.020004  214.455429
# 1506  2020-12-24  221.419998  223.610001  221.199997  222.750000  216.134033
# 1507  2020-12-28  224.449997  226.029999  223.020004  224.960007  218.278412
# 1508  2020-12-29  226.309998  227.179993  223.580002  224.149994  217.492416
# 1509  2020-12-30  225.229996  225.630005  221.470001  221.679993  215.095810
#
# ...

# %%
ms['Close1'] = ms['Close'].shift(-1)
ms.iloc[500:505,:]
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 500  2016-12-27  63.209999  64.070000  63.209999  62.990002  57.567379
# 501  2016-12-28  63.400002  63.400002  62.830002  62.900002  57.303562
# 502  2016-12-29  62.860001  63.200001  62.730000  62.139999  57.221680
# 503  2016-12-30  62.959999  62.990002  62.029999  62.580002  56.530285
# 504  2017-01-03  62.790001  62.840000  62.130001  62.299999  56.930569
#
#        Volume       MA10     MA50  Shares     Close1
# 500  11763200  63.131000  60.5342       1  62.900002
# 501  14653300  63.132000  60.6496       1  62.139999
# 502  10250600  63.154001  60.7544       1  62.580002
# 503  25579900  63.110000  60.8466       1  62.299999
# 504  20694100  63.138001  60.9532       1  62.299999

# %%
ms['Profit'] = [ms.loc[ei, 'Close1']-ms.loc[ei,'Close'] if ms.loc[ei, 'Shares']==1 else 0 for ei in ms.index]

# %%
ms['Profit'].plot()
# Out:
# <Axes: >

# %%
ms['Wealth'] = ms['Profit'].cumsum()

# %%
ms
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2015-01-02   46.660000   47.419998   46.540001   46.330002   40.305370
# 1     2015-01-05   46.369999   46.730000   46.250000   45.650002   39.934723
# 2     2015-01-06   46.380001   46.750000   45.540001   46.230000   39.348598
# 3     2015-01-07   45.980000   46.459999   45.490002   47.590000   39.848541
# 4     2015-01-08   46.750000   47.750000   46.720001   47.189999   41.020802
# ...          ...         ...         ...         ...         ...         ...
# 1505  2020-12-23  223.110001  223.559998  220.800003  222.750000  214.455429
# 1506  2020-12-24  221.419998  223.610001  221.199997  224.960007  216.134033
# 1507  2020-12-28  224.449997  226.029999  223.020004  224.149994  218.278412
# 1508  2020-12-29  226.309998  227.179993  223.580002  221.679993  217.492416
# 1509  2020-12-30  225.229996  225.630005  221.470001         NaN  215.095810
#
# ...

# %%
ms['Wealth'].plot()
# Out:
# <Axes: >
